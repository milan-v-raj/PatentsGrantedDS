# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (3.11.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (7.34.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (2.0.36)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (0.5.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)

# %%
# %load_ext sql
# %sql sqlite:///combined_data.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import pandas as pd
import sqlite3

# Replace with the actual names of your uploaded CSV files
df1 = pd.read_csv('/content/application_details_granted_2018_updated.csv')
df2 = pd.read_csv('/content/application_details_granted_2019_updated.csv')
df3 = pd.read_csv('/content/application_details_granted_2020_updated.csv')
df4 = pd.read_csv('/content/application_details_granted_2021_updated.csv')
df5 = pd.read_csv('/content/application_details_granted_2022_updated.csv')

# Concatenate the DataFrames
df = pd.concat([df1, df2, df3, df4, df5], axis=0)

# Create sqLite connection and save combined to SQL
conn = sqlite3.connect('combined_data.db')
df.to_sql('combined_table', con=conn, if_exists='replace', index=False)

# a cursor object
cursor = conn.cursor()

# Query
cursor.execute("SELECT * FROM combined_table LIMIT 100;")
results = cursor.fetchall()

# Optionally, you can print the results
for row in results:
    print(row)
# Out:
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1002/DELNP/2010', '2010-02-15', '"PHASE ANALYSIS MEASUREMENT APPARATUS AND METHOD"', 'PHYSICS', 'Science', 2010, 56.0, 19.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '10068/DELNP/2008', '2008-12-03', '"PATCH FOR MODIFICATION OF THE POWER OF AN OPTICAL COMPONENT"', 'ELECTRONICS', 'Technology', 2008, 20.0, 34.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'DIVISIONAL PCT NATIONAL PHASE APPLICATION', '10069/DELNP/2008', '2008-12-03', '"A METHOD FOR DRIVING OR PUSHING PILES"', 'CIVIL', 'Industrial', 2008, 37.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '10300/DELNP/2012', '2012-11-27', 'TARGET POINT RECOGNITION METHOD AND SURVEYING INSTRUMENT', 'PHYSICS', 'Science', 2012, 29.0, 15.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '10397/DELNP/2012', '2012-11-29', '"ADSORBENT FOR FEED AND PRODUCTS PURIFICATION IN BENZENE SATURATION PROCESS"', 'CHEMISTRY', 'Science', 2012, 17.0, 10.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'ORDINARY APPLICATION', '1063/KOL/2013', '2013-09-12', "'A METHOD OF HEATING CLEANING SOLVENTS TO ACIDIC RANGE FOR REMOVING MILL SCALE RUST FORMED DURING MANUFACTURING STORAGE AND FABRICATION AND BOILER OPERATIONAL STAGES OF SUB CRITICAL SUPER CRITICAL DRUM TYPE/ONCE THROUGH BOILERS'", 'CHEMISTRY', 'Science', 2013, 13.0, 6.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'ORDINARY APPLICATION', '1073/MUM/2007', '2007-06-06', 'SINGLE USE LOCK SYSTEM', 'CIVIL', 'Industrial', 2007, 15.0, 5.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'ORDINARY APPLICATION', '1097/CHE/2011', '2011-03-31', '“A NETWORK ELEMENT FOR A TELECOMMUNICATION SYSTEM”', 'ELECTRICAL', 'Industrial', 2011, 13.0, 8.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '1116/MUMNP/2011', '2011-06-01', '“PROCESS FOR REMOVING BY-PRODUCTS FROM N-VINYLAMIDES”', 'CHEMISTRY', 'Science', 2011, 12.0, 17.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '116/KOLNP/2010', '2010-01-11', 'CRANKCASE VENTILATION SYSTEM WITH PUMPED SCAVENGED OIL', 'MECHANICAL', 'Industrial', 2010, 23.0, 30.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'CONVENTION APPLICATION', '119/KOL/2009', '2009-01-21', 'A METHOD OF ENHANCING CATALYST PERFORMANCE IN A VEHICLE BY ENGINE LOAD ADJUSTMENT', 'CHEMISTRY', 'Science', 2009, 19.0, 18.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '1198/KOLNP/2008', '2008-03-24', 'HIGH MILK SOLID CHOCOLATE COMPOSITION', 'FOOD', 'Others', 2008, 24.0, 13.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'ORDINARY APPLICATION', '1222/CHE/2011', '2011-04-07', 'PROCESS FOR THE PREPARATION OF ALKYL/ARYL THIOPYRAZOLES', 'CHEMISTRY', 'Science', 2011, 20.0, 16.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'CONVENTION APPLICATION', '1312/KOL/2008', '2008-07-31', 'AN IMMUNOASSAY REAGENT', 'BIOTECHNOLOGY', 'Science', 2008, 28.0, 18.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'ORDINARY APPLICATION', '1319/CHE/2009', '2009-06-04', 'DETACHABLE AND CHANGEABLE HEM', 'MECHANICAL', 'Industrial', 2009, 13.0, 3.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '132/DELNP/2013', '2013-01-04', 'SEPARATION METHOD AND METHOD FOR PRODUCING ISOCYANATE', 'CHEMISTRY', 'Science', 2013, 216.0, 12.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1332/DELNP/2010', '2010-02-25', '"A PROCESS FOR PRODUCING A SUSPENSION OF CELLULOSE PARTICLES"', 'POLYMER', 'Science', 2010, 17.0, 16.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'ORDINARY APPLICATION', '1336/KOL/2011', '2011-10-17', 'SKIN CARE COMPOSITION CONTAINING ACTIVES IN HIGH INTERFACIAL PHASE EMULSIFICATION SYSTEM', 'CHEMISTRY', 'Science', 2011, 16.0, 10.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '1343/MUMNP/2010', '2010-06-24', '“IMPROVEMENTS IN OR RELATING TO NETWORKS”', 'ELECTRONICS', 'Technology', 2010, 18.0, 22.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '1344/MUMNP/2010', '2010-06-24', 'METHOD AND APPARATUS FOR MONITORING THE OPERABILITY OF A TRAVELLING GRATE IN A SINTERING MACHINE', 'MECHANICAL', 'Industrial', 2010, 21.0, 19.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '1387/CHENP/2011', '2011-02-28', 'SYSTEM AND METHOD OF SERVING GATEWAY HAVING MOBILE PACKET PROTOCOL APPLICATION-AWARE PACKET MANAGEMENT', None, None, 2011, 32.0, 15.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'ORDINARY APPLICATION', '1392/KOL/2008', '2008-08-19', 'DISSOLVABLE FILM AND METHOD OF PREPARATION', 'POLYMER', 'Science', 2008, 19.0, 14.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '1400/CHENP/2010', '2010-03-11', 'RESOURCE SCHEDULING ENABLING PARTIALLY-CONSTRAINED RETRANSMISSION', 'ELECTRONICS', 'Technology', 2010, 72.0, 14.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'ORDINARY APPLICATION', '1441/MUM/2012', '2012-06-11', 'A CATALYST COMPOSITION AND A PROCESS FOR SELECTIVE HYDROGENATION OF METHYL ACETYLENE AND PROPADIENE', 'CHEMISTRY', 'Science', 2012, 35.0, 29.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1470/DELNP/2012', '2012-02-17', '"PROCESS FOR MAKING A FLEXIBLE POLYURETHANE FOAM"', 'POLYMER', 'Science', 2012, 18.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'ORDINARY APPLICATION', '1544/DEL/2011', '2011-05-31', 'WAKE-UP SIGNAL RECEIVER FOR ACTIVE RFID TAGS', 'ELECTRONICS', 'Technology', 2011, 16.0, 12.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1571/DELNP/2008', '2008-02-22', '"ADJUSTABLE MULTIBAND ANTENNA"', 'ELECTRICAL', 'Industrial', 2008, 22.0, 14.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '1577/CHENP/2012', '2012-02-21', 'ELECTROMAGNETIC FUEL INJECTION VALVE', 'MECHANICAL', 'Industrial', 2012, 23.0, 4.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1585/DELNP/2010', '2010-03-08', '"ADAPTIVE BRAKE SCHEME DURING A LOCOMOTIVE DISTRIBUTED POWER COMMUNICATION LOSS"', 'MECHANICAL', 'Industrial', 2010, 24.0, 13.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '1635/KOLNP/2009', '2009-04-30', 'IMPLANTABLE REPAIR DEVICE', 'MECHANICAL', 'Industrial', 2009, 26.0, 36.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'ORDINARY APPLICATION', '1639/DEL/2007', '2007-08-02', 'A SORTING UNIT FOR A FRUIT SORTING AND GRADING MACHINE', 'MECHANICAL', 'Industrial', 2007, 23.0, 9.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '1641/KOLNP/2011', '2011-04-20', 'METHOD FOR PRODUCING BETA-SANTALENE', 'BIOTECHNOLOGY', 'Science', 2011, 40.0, 18.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1679/DELNP/2007', '2007-03-02', '"A WIRELESS TERMINAL FOR PROVIDING A LOCATION BASED SERVICE"', 'ELECTRONICS', 'Technology', 2007, 24.0, 24.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'ORDINARY APPLICATION', '1728/KOL/2007', '2007-12-26', 'ENZYMATIC TRANSESTERIFICATION OF JATROPA OIL', 'BIOCHEMISTRY', 'Science', 2007, 8.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'CONVENTION APPLICATION', '173/DEL/2006', '2006-01-23', '"METHOD AND SYSTEM INTEGRATING MULTIPLE IDENTIES, IDENNTITY MECHANISMS AND IDENTITY MECHANISMS AND IDENTITY PROVIDERS IN A SINGLE USER PARADIGM"', 'COMPUTER', 'Technology', 2006, 17.0, 20.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'CONVENTION APPLICATION', '1744/KOL/2008', '2008-10-15', 'VEHICLE COWL DISPOSED REARWARD OF A FRONT WHEEL OF A MOTORCYCLE', 'MECHANICAL', 'Industrial', 2008, 21.0, 10.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1754/DELNP/2010', '2010-03-12', '"RATIONALLY DESIGNED, SYNTHETIC HUMAN ANTIBODY LIBRARIES AND USES THEREFOR"', 'BIOTECHNOLOGY', 'Science', 2010, 261.0, 72.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '1756/KOLNP/2010', '2010-05-14', 'DRIVE FOR TRANSIT DOOR', 'MECHANICAL', 'Industrial', 2010, 11.0, 4.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'ORDINARY APPLICATION', '1794/DEL/2009', '2009-09-01', '"A SYSTEM FOR AUTOMATIC STOP AND START OF TRACTOR TO REDUCE FUEL CONSUMPTION"', 'MECHANICAL', 'Industrial', 2009, 7.0, 5.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '1816/KOLNP/2009', '2009-05-15', 'CALIPER BRAKE DEVICE FOR VEHICLE', 'MECHANICAL', 'Industrial', 2009, 36.0, 12.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '1817/KOLNP/2010', '2010-05-19', 'HONEYCOMB STRUCTURED BODY', 'MECHANICAL', 'Industrial', 2010, 49.0, 2.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1828/DELNP/2009', '2009-03-19', '"BELLOWS COMPRISING A RECEIVER FOR A RETAINING RING AND METHOD FOR PRODUCING THE SAME"', 'MECHANICAL', 'Industrial', 2009, 20.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '1831/MUMNP/2008', '2008-08-25', 'MOBILE SPINDLE LOCK MECHANISM', 'ELECTRICAL', 'Industrial', 2008, 27.0, 24.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '1834/MUMNP/2011', '2011-09-05', 'FLEXIBLE STRIP STEEL PROCESSING LINE SUITABLE FOR PRODUCING VARIOUS HIGH-STRENGTH STEEL', 'CHEMISTRY', 'Science', 2011, 31.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1843/DELNP/2009', '2009-03-20', '"ENAMELING STEEL SHEET, OUTSTANDINGLY EXCELLENT IN FISHSCALE RESISTNCE AND METHOD OF PRODUCING THE SAME"', 'METALLURGY', 'Industrial', 2009, 54.0, 12.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1874/DELNP/2010', '2010-03-17', 'RNA VACCINES', 'BIOTECHNOLOGY', 'Science', 2010, 69.0, 15.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'CONVENTION APPLICATION', '1880/KOL/2008', '2008-11-03', 'METHOD AND APPARATUS TO CONTROL ENGINE TORQUE TO PEAK MAIN PRESSURE FOR A HYBRID POWERTRAIN SYSTEM', 'MECHANICAL', 'Industrial', 2008, 49.0, 14.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '1885/MUMNP/2010', '2010-09-07', 'A CONTROL SYSTEM AND A METHOD FOR CONTROLLING A WIND TURBINE', 'MECHANICAL', 'Industrial', 2010, 28.0, 30.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1912/DELNP/2011', '2011-03-15', '"PRODUCING METHOD OF SINTER"', 'METALLURGY', 'Industrial', 2011, 54.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1934/DELNP/2006', '2006-04-10', '"A METHOD OF PERFORMING SPATIAL PROCESSING AT A RECEIVER IN A WIRELESS MULTIPLE-INPUT MULTIPLE-OUTPUT (MEMO) COMMUNICATION SYSTEM"', 'COMPUTER', 'Technology', 2006, 35.0, 22.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'CONVENTION APPLICATION', '1936/DEL/2010', '2010-08-16', '"EXHAUST PIPE SUPPORT STRUCTURE"', 'MECHANICAL', 'Industrial', 2010, 15.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '1971/CHENP/2010', '2010-04-08', 'REMOVAL OF CARBON DIOXIDE FROM A FEED GAS', 'CHEMISTRY', 'Science', 2010, 20.0, 23.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '1971/DELNP/2010', '2010-03-19', '"LH LIQUID FORMULATIONS"', 'CHEMISTRY', 'Science', 2010, 49.0, 30.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '1975/MUMNP/2009', '2009-10-22', '“INPUT METHOD EDITOR HAVING A SECONDARY LANGUAGE MODE”', 'COMPUTER', 'Technology', 2009, 23.0, 22.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '204/CHENP/2009', '2009-01-12', 'PEPTIDE FRAGMENTS FOR INDUCING SYNTHESIS OF EXTRACELLULAR MATRIX PROTEINS', 'BIOTECHNOLOGY', 'Science', 2009, 27.0, 24.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '2040/MUMNP/2011', '2011-09-29', 'APPARATUS AND METHOD FOR RECOVERY OF ACETIC ACID FROM AN AQUEOUS SOLUTION THEREOF', 'CHEMISTRY', 'Science', 2011, 26.0, 20.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '2048/KOLNP/2007', '2007-06-06', 'A PROGRESSIVE OPHTHALMIC LENS AND METHOD OF PRODUCING A PROGRESSIVE OPHTHALMIC LENS', 'PHYSICS', 'Science', 2007, 35.0, 16.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'CONVENTION APPLICATION', '2060/DEL/2009', '2009-10-01', 'HYDRAULIC MACHINE', 'MECHANICAL', 'Industrial', 2009, 35.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'CONVENTION APPLICATION', '2063/DEL/2008', '2008-09-02', '"CYLINDER LOCK PROTECT APPARATUS"', 'CIVIL', 'Industrial', 2008, 25.0, 6.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'ORDINARY APPLICATION', '2073/MUM/2008', '2008-09-26', 'PHARMACEUTICAL COMPOSITION COMPRISING COENZYME Q10', 'CHEMISTRY', 'Science', 2008, 20.0, 18.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '2088/MUMNP/2010', '2010-10-01', '“BOUNDARY ARTIFACT CORRECTION WITHIN VIDEO UNITS”', 'ELECTRONICS', 'Technology', 2010, 75.0, 52.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '2098/CHENP/2011', '2011-03-25', 'EUI BASED REMOTE DATABASE FOR DYNAMIC DEVICE CONTROL', 'COMPUTER', 'Technology', 2011, 27.0, 15.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'CONVENTION APPLICATION', '2100/MUM/2008', '2008-09-29', 'COVER MEMBER, DEVELOPING CARTRIDGE AND DEVELOPING UNIT FOR IMAGE FORMING APPARATUS', 'PHYSICS', 'Science', 2008, 27.0, 24.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '2107/CHENP/2011', '2011-03-28', 'PROCESS FOR THE PURIFICATION OF AN AQUEOUS STREAM COMING FROM THE FISCHER-TROPSCH REACTION', 'CHEMISTRY', 'Science', 2011, 30.0, 37.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '2124/CHENP/2009', '2009-04-20', 'PROCESS FOR CHROMOSOMAL INTEGRATION OAND DNA SEQUENCE REPLACEMENT IN CLOSTRIDIA', 'BIOTECHNOLOGY', 'Science', 2009, 27.0, 29.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'ORDINARY APPLICATION', '2138/CHE/2008', '2008-09-01', 'A NOVEL PROCESS FOR THE PREPARATION OF GABAPENTIN', 'CHEMISTRY', 'Science', 2008, 32.0, 10.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'ORDINARY APPLICATION', '2145/CHE/2008', '2008-09-02', 'AN INTEGRATED FLUID LEVEL SENSOR WITH REED SWITCH', 'MECHANICAL', 'Industrial', 2008, 21.0, 17.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'ORDINARY APPLICATION', '2150/DEL/2004', '2004-10-29', '"PROCESS OF MAKING STABLE NEEM MELIACIN(S) CONCENTRATES AND PRODUCTS WITH CONTROLLED ACTIVE INGREDIENT RELEASE"', 'BIOCHEMISTRY', 'Science', 2004, 19.0, 23.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '2175/KOLNP/2009', '2009-06-10', 'PROVIDING LOCATION BASED SERVICES FOR MOBILE DEVICES', 'ELECTRONICS', 'Technology', 2009, 31.0, 8.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '2260/KOLNP/2010', '2010-06-21', 'CELL SEARCH METHOD FOR MULTI-MODE TELECOMMUNICATION APPARATUS AND SUCH APPARATUS FOR IMPLEMENTING THE METHOD', 'ELECTRONICS', 'Technology', 2010, 23.0, 17.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'ORDINARY APPLICATION', '2269/DEL/2004', '2004-11-16', '"A PROCESS FOR PREPARATION OF POLYMER ELECTROLYTE FOR PROTON EXCHANGE MEMBRANE FUEL CELL"', 'CHEMISTRY', 'Science', 2004, 15.0, 8.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '2328/MUMNP/2010', '2010-11-01', 'DUAL LEAF VEHICLE SUSPENSION WITH J-SHAPED SPRING ELEMENT', 'MECHANICAL', 'Industrial', 2010, 21.0, 20.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '2393/MUMNP/2009', '2009-12-23', 'DEVICE FOR REMOVING DUST FROM PHARMACEUTICAL TABLETS OR CAPSULES', 'MECHANICAL', 'Industrial', 2009, 27.0, 19.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'ORDINARY APPLICATION', '240/KOL/2010', '2010-03-11', 'PRODUCTION OF CATECHINS FROM NATURAL SOURCES USING MEMBRANE BASED TECHNOLOGY', None, None, 2010, 29.0, 9.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'DIVISIONAL CONVENTION APPLICATION', '2405/CHE/2009', '2009-10-01', 'CROSS-LAMINATE OF ORIENTED FILMS, METHOD OF MANUFACTURING SAME, AND COEXTRUSION DIE SUITABLE IN THE PROCESS', 'POLYMER', 'Science', 2009, 49.0, 17.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '2450/DELNP/2009', '2009-04-15', '"SEALED SINGLE-DOSE BREAK-OPEN PACKAGE, AND PACKING METHOD AND MACHINE FOR PRODUCING A SINGLE-DOSE BREAK-OPEN PACKAGE"', 'MECHANICAL', 'Industrial', 2009, 34.0, 15.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '246/CHENP/2012', '2012-01-06', 'CLOSURE AND CONTAINER HAVING THE SAME', 'MECHANICAL', 'Industrial', 2012, 33.0, 9.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'DIVISIONAL PCT NATIONAL PHASE APPLICATION', '2468/KOLNP/2009', '2009-07-06', 'A MOLDING DEVICE USED IN A VACUUM SEALED PROCESS', 'METALLURGY', 'Industrial', 2009, 32.0, 2.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'ORDINARY APPLICATION', '2476/MUM/2008', '2008-11-24', 'STABLE PHARMACEUTICAL COMPOSITION OF OLOPATADINE', 'CHEMISTRY', 'Science', 2008, 14.0, 7.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '2491/MUMNP/2011', '2011-11-23', '"A COMPOSITION COMPRISING PARTICLES OF INDOMETHACIN"', 'CHEMISTRY', 'Science', 2011, 182.0, 39.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '2517/CHENP/2011', '2011-04-15', '"COMPONENT FOR THE DRILLING AND FOR THE EXPLOITATION OF HYDROCARBON WELLS"', 'MECHANICAL', 'Industrial', 2011, 20.0, 16.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '255/CHENP/2012', '2012-01-06', 'POLYAMIDE-POLYDIENE BLENDS WITH IMPROVED OXYGEN REACTIVITY', 'POLYMER', 'Science', 2012, 31.0, 13.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'ORDINARY APPLICATION', '2559/MUM/2009', '2009-11-04', 'AN IMPROVED PROCESS FOR PREPARATION OF TAXANE DERIVATIVES', 'CHEMISTRY', 'Science', 2009, 17.0, 9.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '2590/KOLNP/2009', '2009-07-14', 'QUALITY SCALABLE VIDEO DATA STREAM', None, None, 2009, 68.0, 21.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'ORDINARY APPLICATION', '2594/MUM/2008', '2008-12-12', 'VERTICAL MUFFLER MOUNTING STRUCTURE FOR VEHICLES', 'MECHANICAL', 'Industrial', 2008, 15.0, 8.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'CONVENTION APPLICATION', '2597/DEL/2010', '2010-10-29', 'ROTOR BLADE WITH DRAINAGE BORE HOLE', 'MECHANICAL', 'Industrial', 2010, 28.0, 13.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '2600/DELNP/2006', '2006-05-09', '"METHOD AND APPARATUS FOR REPORTING WLAN CAPABILITIES OF A DUAL MODE GPRS/WLAN OR UMTS/WLAN WTRU"', 'ELECTRONICS', 'Technology', 2006, 23.0, 10.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '2614/CHENP/2012', '2012-03-21', 'METHOD, DEVICE AND SYSTEM FOR ALLOCATING ADDRESS IN IP NETWORK', 'ELECTRONICS', 'Technology', 2012, 15.0, 8.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'CONVENTION APPLICATION', '2615/DEL/2008', '2008-11-19', '"METHOD AND SYSTEM FOR ENHANCED DISPLAY OF TEMPORAL DATA ON PORTABLE DEVICES"', 'COMPUTER', 'Technology', 2008, 36.0, 10.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'ORDINARY APPLICATION', '2641/DEL/2006', '2006-12-11', '"HERBAL LARVICIDAL MATRIX & THE PROCESS FOR PREPARATION THEREOF"', 'CHEMISTRY', 'Science', 2006, 11.0, 9.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'CONVENTION APPLICATION', '2684/DEL/2008', '2008-11-27', '"COMMUNICATION METHODS IN A NETWORK"', 'ELECTRONICS', 'Technology', 2008, 30.0, 9.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '271/MUMNP/2008', '2008-02-15', 'ANTENNA ARRANGEMENT', 'ELECTRONICS', 'Technology', 2008, 28.0, 48.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '2727/CHENP/2010', '2010-05-07', 'METHOD FOR PRODUCING A VESSEL CLOSURE', 'MECHANICAL', 'Industrial', 2010, 25.0, 18.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Mumbai', 'DIVISIONAL PCT NATIONAL PHASE APPLICATION', '2732/MUMNP/2011', '2011-12-19', '"XYLANASE, NUCLEIC ACID ENCODING IT AND METHOD FOR USING THEM"', 'BIOTECHNOLOGY', 'Science', 2011, 265.0, 87.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '2772/DELNP/2012', '2012-03-30', '"RECYCLING METHOD AND DEVICE FOR RECYCLING WASTE WATER CONTAINING SLURRY FROM A SEMI-CONDUCTOR TREATMENT PROCESS, IN PARTICULAR FROM A CHEMICO-MECHANICAL POLISHING PROCESS"', 'CHEMISTRY', 'Science', 2012, 28.0, 12.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '2781/KOLNP/2009', '2009-07-30', 'CUTTING DEVICE', 'MECHANICAL', 'Industrial', 2009, 22.0, 15.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Delhi', 'CONVENTION APPLICATION', '2797/DEL/2010', '2010-11-25', 'LOWER STRUCTURE OF VEHICLE BODY REAR PART', 'MECHANICAL', 'Industrial', 2010, 24.0, 4.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'ORDINARY APPLICATION', '280/KOL/2011', '2011-03-04', 'A NOVEL DEVICE FOR HIGH DISSOLVED OXYGEN VENTING IN DEAERATORS', 'CHEMISTRY', 'Science', 2011, 14.0, 6.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '2808/KOLNP/2009', '2009-08-03', 'APPARATUS FOR MONITORING DISCHARGE PROCESSES IN A CONDUCTOR OF A MEDIUM-VOLTAGE OR HIGH-VOLTAGE SYSTEM', 'ELECTRICAL', 'Industrial', 2009, 29.0, 13.0, '19/04/2023')
# ('01/2018', '05/01/2018', 'Chennai', 'CONVENTION APPLICATION', '2822/CHE/2010', '2010-09-25', 'PORTABLE ELECTRONIC DEVICE AND METHOD OF CONTROLLING SAME', 'ELECTRONICS', 'Technology', 2010, 19.0, 15.0, '19/04/2023')

# %%
cursor.execute("SELECT * FROM combined_table ORDER BY rowid DESC LIMIT 100;")
results_desc = cursor.fetchall()
print("Last 100 rows in descending order by rowid:")
for row in results_desc:
    print(row)
# Out:
# Last 100 rows in descending order by rowid:
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9779/DELNP/2012', '2012-11-12', 'CUTTING ELEMENTS FOR EARTH-BORING TOOLS INCLUDING SACRIFICIAL\r\nSTRUCTURES IN INDENTATIONS IN CUTTING FACES OF DIAMOND TABLES,\r\nAND RELATED EARTH-BORING TOOLS AND METHODS', 'MECHANICAL', 'Industrial', 2012, 30.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'ORDINARY APPLICATION', '977/MUM/2015', '2015-03-24', 'SYSTEM AND METHOD FOR THE GENERATION OF THREE DIMENSIONAL MEDICAL RAPID PROTOTYPING COMPUTER TOMOGRAPHY PROTOCOL (MRCP) MODEL UTILIZING A DIGITAL RADIOGRAPHIC IMAGE', 'MECHANICAL', 'Industrial', 2015, 26.0, 9.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '977/KOLNP/2014', '2014-05-07', 'SYSTEM AND METHOD FOR A DISTRIBUTED VIRTUAL DESKTOP INFRASTRUCTURE', 'COMPUTER', 'Technology', 2014, 26.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9735/DELNP/2012', '2012-11-09', 'METHODS AND APPARATUS FOR POSITIONING MEASUREMENTS IN MULTI ANTENNA TRANSMISSION SYSTEMS', 'COMMUNICATION', 'Technology', 2012, 58.0, 30.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9679/DELNP/2011', '2011-12-09', '"SEMICONDUCTOR LIGHT EMITTING DIODES HAVING REFLECTIVE STRUCTURES AND METHODS OF FABRICATING SAME"', 'ELECTRONICS', 'Technology', 2011, 49.0, 19.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9659/DELNP/2013', '2013-11-08', 'TOLEROGENIC SYNTHETIC NANOCARRIERS', 'BIOCHEMISTRY', 'Science', 2013, 101.0, 44.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9648/DELNP/2013', '2013-11-08', 'CONTROL DEVICE FOR A VEHICLE BRAKE SYSTEM  AND METHOD FOR OPERATING A VEHICLE BRAKE SYSTEM', 'MECHANICAL', 'Industrial', 2013, 29.0, 11.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9615/DELNP/2013', '2013-11-08', 'WATER PUMP MOTOR USING A WATERPROOF STATOR  AND WATER PUMP', 'ELECTRICAL', 'Industrial', 2013, 31.0, 16.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9581/DELNP/2011', '2011-12-07', 'QUIESCENT STATE RETENTION MODE FOR PROCESSOR', 'COMPUTER', 'Technology', 2011, 29.0, 15.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '954/MUMNP/2014', '2014-05-21', '"METHOD FOR PREPARING ANODE ACTIVE MATERIAL, ANODE ACTIVE MATERIAL PREPARED THEREFROM AND LITHIUM SECONDARY BATTERY HAVING THE SAME"', 'ELECTRICAL', 'Industrial', 2014, 19.0, 16.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'CONVENTION APPLICATION', '944/DEL/2013', '2013-03-28', 'WAVE-LENGTH CONVERSION INORGANIC MEMBER, METHOD FOR MANUFACTURING THE SAME, AND LIGHT EMITTING DEVICE', 'PHYSICS', 'Science', 2013, 202.0, 15.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Kolkata', 'PCT NATIONAL PHASE APPLICATION', '943/KOLNP/2015', '2015-04-07', 'DEVICE FOR PRODUCING CONTAINER PRODUCTS CONSISTING OF PLASTIC MATERIALS', 'MECHANICAL', 'Industrial', 2015, 34.0, 16.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9407/DELNP/2013', '2013-10-31', 'SAFETY SYRINGE FOR NEEDLELESS INJECTOR', 'BIOMEDICAL', 'Science', 2013, 25.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'CONVENTION APPLICATION', '935/CHE/2015', '2015-02-26', 'ASSEMBLY OF TWO CONCENTRIC PARTS AND A BEARING BETWEEN SAID PARTS', 'MECHANICAL', 'Industrial', 2015, 24.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'ORDINARY APPLICATION', '933/MUM/2011', '2011-03-28', 'MECHANICAL ARRANGEMENT SUPPORTING INTEGRATED INSULATED\r\nDRIVE SHAFT IN ELECTRIC POLE', 'ELECTRICAL', 'Industrial', 2011, 14.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9273/DELNP/2013', '2013-10-28', 'PACKAGING FOR MEDICAL CONTAINERS', 'POLYMER', 'Science', 2013, 16.0, 14.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'PCT NATIONAL PHASE APPLICATION', '924/MUMNP/2012', '2012-04-13', '“MONITORING DEVICE FOR MANGEMENT OF INSULIN DELIVERY”', 'COMPUTER', 'Technology', 2012, 68.0, 45.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '924/DELNP/2014', '2014-02-07', 'GUIDE WIRE INCORPORATING A HANDLE', 'BIOMEDICAL', 'Science', 2014, 59.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '9182/CHENP/2014', '2014-12-21', 'METHODS AND APPARATUSES FOR SEPARATING LIQUID PARTICLES FROM A GAS LIQUID STREAM', 'MECHANICAL', 'Industrial', 2014, 37.0, 45.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9129/DELNP/2014', '2014-10-31', 'METHOD FOR UPLINK DOWNLINK INTERFERENCE MITIGATION IN HETEROGENEOUS NETWORK', 'COMMUNICATION', 'Technology', 2014, 40.0, 64.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '9109/DELNP/2014', '2014-10-30', 'CAR ENZYMES AND IMPROVED PRODUCTION OF FATTY ALCOHOLS', 'BIOTECHNOLOGY', 'Science', 2014, 134.0, 57.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'ORDINARY APPLICATION', '902/DEL/2009', '2009-05-01', '"A MODIFIED MEDIUM FOR CO-CULTIVATION OF SEBACINALES FUNGI WITH PLANTS OF LAMIACEAE FAMILY"', 'MECHANICAL', 'Industrial', 2009, 15.0, 7.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '8945/CHENP/2014', '2014-12-10', 'VIDEO PARAMETER SET FOR HEVC AND EXTENSIONS', 'COMMUNICATION', 'Technology', 2014, 95.0, 49.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'ORDINARY APPLICATION', '892/MUM/2009', '2009-04-01', 'DIFFERENTIAL CONTACT MOVEMENT MECHANISM IN FULL WIDTH FEEDER MODULES OF MOTOR CONTROL CENTER (MCC) SWITCHBOARDS', 'ELECTRICAL', 'Industrial', 2009, 14.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8907/DELNP/2013', '2013-10-14', 'HYDROCELLULAR ABSORBENT DRESSING  AND USES THEREOF FOR THE TREATMENT OF CHRONIC AND ACUTE WOUNDS', 'BIOMEDICAL', 'Science', 2013, 23.0, 14.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8870/DELNP/2015', '2015-09-28', 'MECHANICAL SEAL ARRANGEMENT HAVING SLIDING SURFACES OF DIFFERING HARDNESS', 'MECHANICAL', 'Industrial', 2015, 16.0, 15.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '886/DELNP/2013', '2013-01-29', 'RAIL FOR SUSPENDED CONVEYORS AND SUSPENDED CRANES', 'MECHANICAL', 'Industrial', 2013, 20.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'CONVENTION APPLICATION', '88/DEL/2015', '2015-01-12', 'COMPUTER SYSTEM', 'COMPUTER', 'Technology', 2015, 32.0, 5.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'ORDINARY APPLICATION', '879/DEL/2015', '2015-03-30', 'A VEHICLE AND METHOD FOR DETECTING AND NEUTRALIZING AN INCENDIARY OBJECT', 'PHYSICS', 'Science', 2015, 30.0, 23.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8773/DELNP/2013', '2013-10-09', 'SMS MESSAGING SYSTEM ACCOMMODATION VARIABLE ENTRIES FOR LOTTERIES', 'ELECTRONICS', 'Technology', 2013, 42.0, 24.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8765/DELNP/2015', '2015-09-24', 'METAL COATED STEEL STRIP', 'CHEMISTRY', 'Science', 2015, 21.0, 18.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8726/DELNP/2012', '2012-10-08', 'A DEVICE FOR MONITORING THE CONNECTION OF A BLOOD TREATMENT UNIT TO\r\nTHE FLUID SYSTEM OF AN EXTRACORPOREAL BLOOD TREATMENT APPARATUS', 'BIOMEDICAL', 'Science', 2012, 40.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8693/DELNP/2011', '2011-11-08', '"COMMUNICATION APPARATUS AND COMMUNICATION METHOD, AND COMMUNICATION SYSTEM"', 'COMMUNICATION', 'Technology', 2011, 83.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8675/DELNP/2013', '2013-10-07', 'AIRCRAFT ENGINE ANNULAR SHROUD COMPRISING AN OPENING FOR THE INSERTION OF BLADES', 'MECHANICAL', 'Industrial', 2013, 24.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '8662/CHENP/2013', '2013-10-28', 'BROWSING SYSTEM  TERMINAL  IMAGE SERVER  PROGRAM  COMPUTER READABLE RECORDING MEDIUM RECORDING SAID  PROGRAM  AND METHOD', 'COMPUTER', 'Technology', 2013, 73.0, 16.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8660/DELNP/2013', '2013-10-04', 'METHOD AND APPARATUS FOR ADAPTING THE DATA TRANSMISSION SECURITY IN A SERIAL BUS SYSTEM', 'COMMUNICATION', 'Technology', 2013, 32.0, 28.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8617/DELNP/2012', '2012-10-04', 'SYSTEM AND METHOD FOR SIGNALING CONTROL INFORMATION IN A MOBILE COMMUNICATION NETWORK', 'COMMUNICATION', 'Technology', 2012, 73.0, 38.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '8610/CHENP/2014', '2014-11-26', 'APPARATUS FOR POINT TO MULTI POINT COMMUNICATION IN COMMUNICATION SYSTEM AND METHOD THEREOF', 'COMMUNICATION', 'Technology', 2014, 43.0, 12.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '8423/CHENP/2010', '2010-12-24', 'METHOD AND COOLER FOR COOLING HOT PARTICULATE MATERIAL', 'MECHANICAL', 'Industrial', 2010, 10.0, 6.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'ORDINARY APPLICATION', '831/MUM/2009', '2009-03-31', 'MODULAR CONTACT HOUSING ASSEMBLY', 'ELECTRICAL', 'Industrial', 2009, 16.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '8272/CHENP/2012', '2012-09-26', 'DETERMINATION OF A LIPID WATER RATIO', 'BIOMEDICAL', 'Science', 2012, 34.0, 15.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '821/CHENP/2015', '2015-02-10', 'INFRASTRUCTURE FOR PROVIDING CLOUD SERVICES', 'COMMUNICATION', 'Technology', 2015, 114.0, 22.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'ORDINARY APPLICATION', '818/DEL/2013', '2013-03-20', 'WATER INJECTOR', 'MECHANICAL', 'Industrial', 2013, 7.0, 6.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8173/DELNP/2012', '2012-09-19', 'TELECOMMUNICATION CHIP CARD  MOBILE TELEPHONE DEVICE  AND COMPUTER READABLE STORAGE MEDIUM', 'COMPUTER', 'Technology', 2012, 36.0, 18.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '8138/DELNP/2012', '2012-09-18', 'COMMUNICATION CONTROL METHOD AND SMALL-OR-MEDIUM-SCALE BASE STATION', 'COMMUNICATION', 'Technology', 2012, 42.0, 14.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '8130/CHENP/2014', '2014-11-07', 'FLOATING BEARING FOR A STEERING GEAR', 'MECHANICAL', 'Industrial', 2014, 26.0, 11.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '81/DELNP/2014', '2014-01-06', 'DIE SHOE ASSEMBLY WITH BEARING SURFACE MECHANISM  METHOD FOR RETAINING A DIE  AND DIE FOR USE THEREWITH', 'MECHANICAL', 'Industrial', 2014, 41.0, 51.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'ORDINARY APPLICATION', '803/DEL/2015', '2015-03-24', 'AN ELECTROCHEMICAL PROCESS FOR THE PREPARATION OF METALLIC LEAD FOAM', 'CHEMISTRY', 'Science', 2015, 30.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'ORDINARY APPLICATION', '798/DEL/2014', '2014-03-19', 'A ROBOTIC COOKING SYSTEM', 'MECHANICAL', 'Industrial', 2014, 33.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7960/CHENP/2013', '2013-10-01', 'SYSTEM AND METHOD FOR ENABLING SOFTER HANDOVER BY USER EQUIPMENT IN A NON DEDICATED CHANNEL STATE', 'COMMUNICATION', 'Technology', 2013, 86.0, 102.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7945/CHENP/2015', '2015-12-23', 'AIR-BASED FRYER', 'MECHANICAL', 'Industrial', 2015, 35.0, 15.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'DIVISIONAL ORDINARY APPLICATION', '794/CHE/2013', '2013-02-22', 'FERMENTATION MEDIA AND PROCESSES THEREOF', 'BIOCHEMISTRY', 'Science', 2013, 59.0, 16.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7875/DELNP/2014', '2014-09-22', 'THERAPEUTIC AGENT FOR INFLAMMATORY DISEASE', 'BIOTECHNOLOGY', 'Science', 2014, 55.0, 17.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7814/CHENP/2015', '2015-12-18', 'DEVICE FOR THE INSERTION OF PAPER VALUABLES IN CLOSABLE CONTAINERS  WITH CONTROL AND STORAGE OF VALUABLES ENTERING THE CONTAINER', 'MECHANICAL', 'Industrial', 2015, 20.0, 7.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7809/DELNP/2013', '2013-09-05', 'FIBER EMBEDDED HOLLOW NEEDLE FOR PERCUTANEOUS DELIVERY OF LASER ENERGY', 'BIOMEDICAL', 'Science', 2013, 21.0, 11.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7808/DELNP/2013', '2013-09-05', 'LASER GENERATOR FOR DEEP TISSUE LASER TREATMENT USING LOW INTENSITY LASER THERAPY CAUSING SELECTIVE DESTRUCTION OF NOCICEPTIVE NERVES', 'BIOMEDICAL', 'Science', 2013, 14.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Kolkata', 'ORDINARY APPLICATION', '780/KOL/2010', '2010-07-19', 'METHOD FOR PREPARING HIGH STRENGTH STEEL WITH ULTRAFINE GRAINED MICROSTRUCTURE', 'METALLURGY', 'Industrial', 2010, 14.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7775/CHENP/2012', '2012-09-07', 'METHOD, SYSTEM AND BASE STATION SUBSYSTEM FOR REALIZING HANDOVER IN LOCAL SWITCH', 'ELECTRONICS', 'Technology', 2012, 18.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'ORDINARY APPLICATION', '777/MUM/2014', '2014-03-07', 'A MULTI-LAYER POLYMERIC FILM', 'POLYMER', 'Science', 2014, 20.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7726/CHENP/2015', '2015-12-16', 'SUBSTANCE DELIVERY MODULE', 'BIOMEDICAL', 'Science', 2015, 48.0, 19.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '760/DELNP/2013', '2013-01-24', 'FIXING DEVICE', 'MECHANICAL', 'Industrial', 2013, 14.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7598/CHENP/2014', '2014-10-15', 'BODY PULSATING APPARATUS AND METHOD', 'BIOMEDICAL', 'Science', 2014, 65.0, 80.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'ORDINARY APPLICATION', '757/MUM/2015', '2015-03-09', 'Encased vertical drain for soft cohesive soil consolidation and consolidated soft cohesive soil comprising the same', 'CHEMISTRY', 'Science', 2015, 25.0, 29.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Kolkata', 'ORDINARY APPLICATION', '757/KOL/2015', '2015-07-14', 'A PROCESS FOR MANUFACTURE OF PLYWOOD THROUGH MAT', 'CHEMISTRY', 'Science', 2015, 15.0, 4.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7534/DELNP/2015', '2015-08-24', 'MOLDED FLUID FLOW STRUCTURE', 'MECHANICAL', 'Industrial', 2015, 31.0, 16.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'ORDINARY APPLICATION', '750/MUM/2015', '2015-03-09', 'Tray System of Motor Control Centre Module', 'MECHANICAL', 'Industrial', 2015, 19.0, 4.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7457/DELNP/2015', '2015-08-21', 'NON ORIENTED MAGNETIC STEEL SHEET AND METHOD FOR PRODUCING SAME', 'METALLURGY', 'Industrial', 2015, 39.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7378/CHENP/2014', '2014-10-07', 'ABSORBENT ARTICLE', 'POLYMER', 'Science', 2014, 97.0, 12.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7344/CHENP/2015', '2015-11-26', 'A TOOL FOR RETAINING AN ACTIVATOR RING OF A HANGER WITHIN A WELLHEAD ASSEMBLY', 'CIVIL', 'Industrial', 2015, 21.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7207/CHENP/2013', '2013-09-06', 'EPICYCLIC ARRANGEMENTS AND RELATED SYSTEMS AND METHODS', 'MECHANICAL', 'Industrial', 2013, 56.0, 17.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7180/DELNP/2013', '2013-08-13', 'WELL TREATMENT METHODS AND SYSTEMS', 'POLYMER', 'Science', 2013, 23.0, 21.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7160/DELNP/2011', '2011-09-19', 'RICE WRAPPER AND WRAPPED RICE', 'MECHANICAL', 'Industrial', 2011, 43.0, 22.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7157/DELNP/2014', '2014-08-26', 'ELECTRONICALLY ACTUATED LOCKING DIFFERENTIAL HAVING NON ROTATING STATOR AND ARMATURE', 'MECHANICAL', 'Industrial', 2014, 14.0, 16.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7154/DELNP/2015', '2015-08-13', 'DUAL SGLT1/SGLT2 INHIBITORS', 'CHEMISTRY', 'Science', 2015, 147.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Kolkata', 'ORDINARY APPLICATION', '714/KOL/2012', '2012-06-27', 'SYSTEM TO CUT HEAD END OF HOT BAR IN A CONTINUOUS MILL OPERATION AND A METHOD THEREOF', 'ELECTRICAL', 'Industrial', 2012, 21.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7098/DELNP/2013', '2013-08-08', 'NITRIDED STEEL MEMBER AND METHOD FOR PRODUCING SAME', 'METALLURGY', 'Industrial', 2013, 44.0, 4.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '7053/CHENP/2015', '2015-11-16', 'METHOD AND APPARATUS FOR INSPECTING WORKPIECES', 'PHYSICS', 'Science', 2015, 36.0, 33.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '705/DELNP/2015', '2015-01-28', 'STEEL SHEET FOR HOT PRESSING USE  METHOD FOR PRODUCING SAME  AND HOT PRESS STEEL SHEET MEMBER', 'METALLURGY', 'Industrial', 2015, 63.0, 24.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Mumbai', 'ORDINARY APPLICATION', '704/MUM/2014', '2014-02-27', 'LOOP ABSTRACTION FOR MODEL CHECKING', 'COMPUTER', 'Technology', 2014, 36.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '7026/DELNP/2014', '2014-08-21', 'ORAL CARE DEVICE', 'MECHANICAL', 'Industrial', 2014, 50.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '6975/CHENP/2014', '2014-09-22', 'DUAL STRUCTURE STORAGE BOX FOR RAILWAY VEHICLE  AND RAILWAY VEHICLE PROVIDED WITH SAME', 'MECHANICAL', 'Industrial', 2014, 27.0, 7.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'CONVENTION APPLICATION', '697/DEL/2014', '2014-03-11', '"INTERNAL COMBUSTION ENGINE TEST SYSTEM"', 'PHYSICS', 'Science', 2014, 35.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '6962/CHENP/2014', '2014-09-22', 'HIGH STRENGTH COLD ROLLED STEEL SHEET  HIGH STRENGTH GALVANIZED STEEL SHEET AND HIGH STRENGTH GALVANNEALED STEEL SHEET  HAVING EXCELLENT FORMABILITY AND SHAPE FIXABILITY  AND PROCESSES FOR MANUFACTURING SAME', 'MECHANICAL', 'Industrial', 2014, 34.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '6883/DELNP/2014', '2014-08-14', 'HIGH PRESSURE PUMP', 'MECHANICAL', 'Industrial', 2014, 18.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'CONVENTION APPLICATION', '684/DEL/2013', '2013-03-09', 'A PROCESS FOR THE PRODUCTION OF (S,S)-6-BENZYLOCTAHYDRO-1H-PYRROLO[3,4-B]PYRIDINE, AN INTERMEDIATE OF AZABICYCLO PYRIDINE DERIVATIVES', 'CHEMISTRY', 'Science', 2013, 17.0, 9.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'DIVISIONAL PCT NATIONAL PHASE APPLICATION', '6827/DELNP/2014', '2014-08-13', 'POLYMERIZATION CATALYSTS FOR PRODUCING POLYMERS WITH LOW LEVELS OF LONG CHAIN BRANCHING', 'POLYMER', 'Science', 2014, 111.0, 8.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '6801/CHENP/2013', '2013-08-23', 'MULTI-ARRAY ANTENNA', 'ELECTRONICS', 'Technology', 2013, 43.0, 18.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '6788/DELNP/2015', '2015-08-01', 'VALVE SOUND REDUCING TRIM ASSEMBLY WITH PRESSURE RELIEF MECHANISM', 'MECHANICAL', 'Industrial', 2015, 12.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'ORDINARY APPLICATION', '6782/CHE/2015', '2015-12-19', 'PLATE BALLOON FOR INTRACRANIAL BIFURCATION ANEURYSMS', 'BIOMEDICAL', 'Science', 2015, 17.0, 23.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'ORDINARY APPLICATION', '6779/CHE/2015', '2015-12-18', 'SYSTEM AND METHOD FOR VISUALIZATION OF ULTRASOUND VOLUMES', 'COMPUTER', 'Technology', 2015, 28.0, 28.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '6765/DELNP/2015', '2015-07-31', 'INFORMATION PROCESSING DEVICE', 'COMPUTER', 'Technology', 2015, 84.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'ORDINARY APPLICATION', '6737/CHE/2014', '2014-12-30', 'A HOOD HINGE ASSEMBLY', 'MECHANICAL', 'Industrial', 2014, 16.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '672/CHENP/2014', '2014-01-28', 'AN OPTICAL ELEMENT  A LIGHTING SYSTEM AND A LUMINAIRE FOR PROVIDING A SKYLIGHT APPEARANCE', 'ELECTRICAL', 'Industrial', 2014, 28.0, 11.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Kolkata', 'ORDINARY APPLICATION', '670/KOL/2013', '2013-06-05', 'SYSTEM AND METHOD FOR NON-INVASIVE MEASURMENT OF CONCENTRATION OF ANALYTES IN A BIOLOGICAL SAMPLE', 'BIOMEDICAL', 'Science', 2013, 32.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'CONVENTION APPLICATION', '6687/CHE/2015', '2015-12-14', 'METHOD OF PRODUCING A DECORATED COMPONENT FOR A TIMEPIECE OR PIECE OF JEWELLERY, AND COMPONENT MADE BY THE METHOD', 'PHYSICS', 'Science', 2015, 18.0, 14.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PCT NATIONAL PHASE APPLICATION', '6666/DELNP/2013', '2013-07-25', 'RUBBER COMPOSITION AND TIRE PRODUCED USING SAME  AND PROCESS OF PRODUCING RUBBER COMPOSITION', 'POLYMER', 'Science', 2013, 127.0, 39.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'ORDINARY APPLICATION', '6549/CHE/2014', '2015-01-24', 'METHOD AND SYSTEM FOR TRANSITION DATA ANALYSIS', 'ELECTRICAL', 'Industrial', 2015, 18.0, 6.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Delhi', 'PATENT OF ADDITION FOR ORDINARY APPLICATION', '651/DEL/2014', '2014-03-07', 'POLYMERIC SUBSTRATE FOR FLEXIBLE PACKAGING SUITABLE FOR LASER MARKING', 'TEXTILE', 'Others', 2014, 23.0, 20.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'ORDINARY APPLICATION', '6446/CHE/2014', '2014-12-22', 'COOLING SYSTEM FOR A TWO-WHEELED VEHICLE', 'MECHANICAL', 'Industrial', 2014, 23.0, 10.0, '19/04/2023')
# ('52/2022', '30/12/2022', 'Chennai', 'PCT NATIONAL PHASE APPLICATION', '6428/CHENP/2013', '2013-08-08', 'ACQUIRING AND DISPLAYING IMAGES IN REAL TIME', 'ELECTRONICS', 'Technology', 2013, 32.0, 15.0, '19/04/2023')

# %%
cursor.execute("SELECT COUNT(*) AS total_rows FROM combined_table;")
total_rows = cursor.fetchone()[0]
print(f"Total rows: {total_rows}")
# Out:
# Total rows: 120085

# %%
cursor.execute("PRAGMA TABLE_INFO('combined_table');")
total_columns = len(cursor.fetchall())
print(f"Total columns: {total_columns}")
# Out:
# Total columns: 13

# %%
# Step 1: Create invention_category table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS invention_category (
        FIELD_OF_INVENTION TEXT PRIMARY KEY NOT NULL,
        CATEGORY_OF_INVENTION TEXT
    )
''')

# Step 2: Create filing_date table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS filing_date (
        DATE_OF_FILING TEXT PRIMARY KEY NOT NULL,
        FILING_YEAR INTEGER
    )
''')

# Step 3: Create invention_information table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS invention_information (
        TITLE_OF_INVENTION TEXT PRIMARY KEY NOT NULL,
        DATE_OF_FILING TEXT NOT NULL,
        FIELD_OF_INVENTION TEXT NOT NULL,
        NO_OF_PAGES INTEGER,
        NO_OF_CLAIMS INTEGER,
        FOREIGN KEY (DATE_OF_FILING) REFERENCES filing_date(DATE_OF_FILING),
        FOREIGN KEY (FIELD_OF_INVENTION) REFERENCES invention_category(FIELD_OF_INVENTION)
    )
''')

# Step 4: Create application_information table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS application_information (
        APPLICATION_NUMBER TEXT PRIMARY KEY NOT NULL,
        APPLICATION_TYPE_DESC TEXT,
        IPO_LOCATION TEXT,
        PUBLICATION_DATE TEXT,
        TITLE_OF_INVENTION TEXT NOT NULL,
        FOREIGN KEY (TITLE_OF_INVENTION) REFERENCES invention_information(TITLE_OF_INVENTION)
    )
''')

# Commit the table creation commands
conn.commit()
print("Tables created successfully with specified relationships.")
# Out:
# Tables created successfully with specified relationships.

# %%
# Split data into different DataFrames based on table columns
# Prepare the invention_category data, dropping rows with null values and keeping unique FIELD_OF_INVENTION values
invention_category_df = df[['FIELD_OF_INVENTION', 'CATEGORY_OF_INVENTION']].drop_duplicates()
invention_category_df = invention_category_df.dropna(subset=['FIELD_OF_INVENTION', 'CATEGORY_OF_INVENTION'])
# Remove duplicates based on FIELD_OF_INVENTION, keeping only the first occurrence
invention_category_df = invention_category_df.drop_duplicates(subset=['FIELD_OF_INVENTION'])

# Insert cleaned data into the invention_category table
invention_category_df.to_sql('invention_category', conn, if_exists='replace', index=False)

# 2. Filing Date
filing_date_df = df[['DATE_OF_FILING', 'FILING_YEAR']].drop_duplicates()

# 3. Invention Information
invention_information_df = df[['TITLE_OF_INVENTION', 'DATE_OF_FILING', 'FIELD_OF_INVENTION', 'NO_OF_PAGES', 'NO_OF_CLAIMS']].drop_duplicates()
invention_information_df = invention_information_df.dropna(subset=['TITLE_OF_INVENTION', 'DATE_OF_FILING', 'FIELD_OF_INVENTION', 'NO_OF_PAGES', 'NO_OF_CLAIMS'])

# 4. Application Information
application_information_df = df[['APPLICATION_NUMBER', 'APPLICATION_TYPE_DESC', 'IPO_LOCATION', 'PUBLICATION_DATE', 'TITLE_OF_INVENTION']].drop_duplicates()

# Insert data into each table using .to_sql
invention_category_df.to_sql('invention_category', conn, if_exists='append', index=False)
filing_date_df.to_sql('filing_date', conn, if_exists='replace', index=False)
invention_information_df.to_sql('invention_information', conn, if_exists='replace', index=False)
application_information_df.to_sql('application_information', conn, if_exists='replace', index=False)

# Commit the transactions
conn.commit()
print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %%
print("Invention Category Table:")
# %sql SELECT * FROM invention_category;
# Out:
# Invention Category Table:
#  * sqlite:///combined_data.db
# Done.
# [('PHYSICS', 'Science'),
#  ('ELECTRONICS', 'Technology'),
#  ('CIVIL', 'Industrial'),
#  ('CHEMISTRY', 'Science'),
#  ('ELECTRICAL', 'Industrial'),
#  ('MECHANICAL', 'Industrial'),
#  ('FOOD', 'Others'),
#  ('BIOTECHNOLOGY', 'Science'),
#  ('POLYMER', 'Science'),
#  ('BIOCHEMISTRY', 'Science'),
#  ('COMPUTER', 'Technology'),
#  ('METALLURGY', 'Industrial'),
#  ('TEXTILE', 'Others'),
#  ('BIOMEDICAL', 'Science'),
#  ('COMMUNICATION', 'Technology'),
#  ('PHYSICS', 'Science'),
#  ('ELECTRONICS', 'Technology'),
#  ('CIVIL', 'Industrial'),
#  ('CHEMISTRY', 'Science'),
#  ('ELECTRICAL', 'Industrial'),
#  ('MECHANICAL', 'Industrial'),
#  ('FOOD', 'Others'),
#  ('BIOTECHNOLOGY', 'Science'),
#  ('POLYMER', 'Science'),
#  ('BIOCHEMISTRY', 'Science'),
#  ('COMPUTER', 'Technology'),
#  ('METALLURGY', 'Industrial'),
#  ('TEXTILE', 'Others'),
#  ('BIOMEDICAL', 'Science'),
#  ('COMMUNICATION', 'Technology')]

# %%
print("\nFiling Date Table:")
# %sql SELECT * FROM filing_date LIMIT 10;
# Out:
# Filing Date Table:
#  * sqlite:///combined_data.db
# Done.
# [('2010-02-15', 2010),
#  ('2008-12-03', 2008),
#  ('2012-11-27', 2012),
#  ('2012-11-29', 2012),
#  ('2013-09-12', 2013),
#  ('2007-06-06', 2007),
#  ('2011-03-31', 2011),
#  ('2011-06-01', 2011),
#  ('2010-01-11', 2010),
#  ('2009-01-21', 2009)]

# %%
print("\nInvention Information Table:")
# %sql SELECT * FROM invention_information LIMIT 10;
# Out:
# Invention Information Table:
#  * sqlite:///combined_data.db
# Done.
# [('"PHASE ANALYSIS MEASUREMENT APPARATUS AND METHOD"', '2010-02-15', 'PHYSICS', 56.0, 19.0),
#  ('"PATCH FOR MODIFICATION OF THE POWER OF AN OPTICAL COMPONENT"', '2008-12-03', 'ELECTRONICS', 20.0, 34.0),
#  ('"A METHOD FOR DRIVING OR PUSHING PILES"', '2008-12-03', 'CIVIL', 37.0, 7.0),
#  ('TARGET POINT RECOGNITION METHOD AND SURVEYING INSTRUMENT', '2012-11-27', 'PHYSICS', 29.0, 15.0),
#  ('"ADSORBENT FOR FEED AND PRODUCTS PURIFICATION IN BENZENE SATURATION PROCESS"', '2012-11-29', 'CHEMISTRY', 17.0, 10.0),
#  ("'A METHOD OF HEATING CLEANING SOLVENTS TO ACIDIC RANGE FOR REMOVING MILL SCALE RUST FORMED DURING MANUFACTURING STORAGE AND FABRICATION AND BOILER OPERATIONAL STAGES OF SUB CRITICAL SUPER CRITICAL DRUM TYPE/ONCE THROUGH BOILERS'", '2013-09-12', 'CHEMISTRY', 13.0, 6.0),
#  ('SINGLE USE LOCK SYSTEM', '2007-06-06', 'CIVIL', 10.0, 5.0),
#  ('“A NETWORK ELEMENT FOR A TELECOMMUNICATION SYSTEM”', '2011-03-31', 'ELECTRICAL', 13.0, 8.0),
#  ('“PROCESS FOR REMOVING BY-PRODUCTS FROM N-VINYLAMIDES”', '2011-06-01', 'CHEMISTRY', 12.0, 17.0),
#  ('CRANKCASE VENTILATION SYSTEM WITH PUMPED SCAVENGED OIL', '2010-01-11', 'MECHANICAL', 23.0, 30.0)]

# %%
print("\nApplication Information Table:")
# %sql SELECT * FROM application_information LIMIT 5;
# Out:
# Application Information Table:
#  * sqlite:///combined_data.db
# Done.
# [('1002/DELNP/2010', 'PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', '"PHASE ANALYSIS MEASUREMENT APPARATUS AND METHOD"'),
#  ('10068/DELNP/2008', 'PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', '"PATCH FOR MODIFICATION OF THE POWER OF AN OPTICAL COMPONENT"'),
#  ('10069/DELNP/2008', 'DIVISIONAL PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', '"A METHOD FOR DRIVING OR PUSHING PILES"'),
#  ('10300/DELNP/2012', 'PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', 'TARGET POINT RECOGNITION METHOD AND SURVEYING INSTRUMENT'),
#  ('10397/DELNP/2012', 'PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', '"ADSORBENT FOR FEED AND PRODUCTS PURIFICATION IN BENZENE SATURATION PROCESS"')]

# %%
# %sql SELECT ai.APPLICATION_NUMBER, ai.APPLICATION_TYPE_DESC, ai.IPO_LOCATION, ai.PUBLICATION_DATE, ii.TITLE_OF_INVENTION, ii.NO_OF_PAGES, ii.NO_OF_CLAIMS FROM application_information ai JOIN invention_information ii ON ai.TITLE_OF_INVENTION = ii.TITLE_OF_INVENTION LIMIT 5;
# Out:
#  * sqlite:///combined_data.db
# Done.
# [('1002/DELNP/2010', 'PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', '"PHASE ANALYSIS MEASUREMENT APPARATUS AND METHOD"', 56.0, 19.0),
#  ('10068/DELNP/2008', 'PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', '"PATCH FOR MODIFICATION OF THE POWER OF AN OPTICAL COMPONENT"', 20.0, 34.0),
#  ('10069/DELNP/2008', 'DIVISIONAL PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', '"A METHOD FOR DRIVING OR PUSHING PILES"', 37.0, 7.0),
#  ('10300/DELNP/2012', 'PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', 'TARGET POINT RECOGNITION METHOD AND SURVEYING INSTRUMENT', 29.0, 15.0),
#  ('10397/DELNP/2012', 'PCT NATIONAL PHASE APPLICATION', 'Delhi', '05/01/2018', '"ADSORBENT FOR FEED AND PRODUCTS PURIFICATION IN BENZENE SATURATION PROCESS"', 17.0, 10.0)]

# %%
	SINGLE USE LOCK SYSTEM

# %%
# %sql SELECT * FROM invention_information WHERE TITLE_OF_INVENTION = 'SINGLE USE LOCK SYSTEM';
# Out:
#  * sqlite:///combined_data.db
# Done.
# [('SINGLE USE LOCK SYSTEM', '2007-06-06', 'CIVIL', 15.0, 5.0)]

# %%
# %sql UPDATE invention_information SET NO_OF_PAGES = 10 WHERE TITLE_OF_INVENTION = 'SINGLE USE LOCK SYSTEM';
# Out:
#  * sqlite:///combined_data.db
# 1 rows affected.
# []

# %%
# %sql SELECT * FROM invention_information WHERE TITLE_OF_INVENTION = 'SINGLE USE LOCK SYSTEM';
# Out:
#  * sqlite:///combined_data.db
# Done.
# [('SINGLE USE LOCK SYSTEM', '2007-06-06', 'CIVIL', 10.0, 5.0)]
